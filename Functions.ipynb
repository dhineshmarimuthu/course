# %% [markdown]
# # Python Functions
#
# A function is a block of code which only runs when it is called.
#
# You can pass data, known as parameters, into a function.
#
# A function can return data as a result

# %%
# In Python a function is defined using the def keyword

def new_function():
    print("Executed")

# %%
new_function()
# Out:
# Executed

# %% [markdown]
# information can be passed into functions as arguments.
#
# Arguments are specified after the function name, inside the parentheses. You can add as many arguments as you want, just separate them with a comma.
#
# The following example has a function with one argument (name). When the function is called, we pass along the Satellite name as argument which is used inside the function to print email id

# %%
def email_generator(name):
    print("Your email id is ",name,"@xyz.com")
email_generator("Cressita")
# Out:
# Your email id is  Cressita @xyz.com

# %% [markdown]
# By default, a function must be called with the correct number of arguments.
#
# Meaning that if your function expects 2 arguments, you have to call the function with 2 arguments, not more, and not less

# %%
# By default, a function must be called with the correct number of arguments. 
# Meaning that if your function expects 2 arguments, 
# you have to call the function with 2 arguments, not more, and not less

def email_generator(name,domain):
    print("Your email id is ",name,"@",domain)
email_generator("Cressita","gmail.com")
# Out:
# Your email id is  Cressita @ gmail.com

# %%
# You can send any data types of argument to a function (string, number, list, dictionary etc.), 
# and it will be treated as the same data type inside the function

def planet(plan_list):
    for i in space_list:
        print(i)
        
plan_list=["Venus","Mars","Jupiter"]
planet(plan_list)
# Out:
# Venus
# Mars
# Jupiter

# %%
# To let a function return a value, use the return statement

def addition(a,b):
    sum=a+b
    return sum
print("sum of values = ",addition(3,5))
# Out:
# sum of values =  8

# %% [markdown]
# # Lambda functions
#
# A lambda function is a small anonymous function.
#
#
# A lambda function can take any number of arguments, but can only have one expression
#
# Syntax: lambda args:expression

# %%
total_cost=lambda price,quantity:price*quantity 

total_cost(10,5)
# Out:
# 50

# %%
# We can also use conditions inside lambda function

total_cost=lambda cost,discount:cost-discount if cost>=100 else cost
total_cost(55,50)
# Out:
# 55
