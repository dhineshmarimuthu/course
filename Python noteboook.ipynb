# %% [markdown]
# ![Blue%20Modern%20minimal%20Futuristic%20Hologram%20Shape%20%20NFT%20Twitter%20Header.png](attachment:Blue%20Modern%20minimal%20Futuristic%20Hologram%20Shape%20%20NFT%20Twitter%20Header.png)

# %% [markdown]
# # Python Programming

# %% [markdown]
# # First program in python

# %%
print("Demo text ")
# Out:
# Demo text

# %% [markdown]
# # Indentation

# %% [markdown]
# Indentation refers to the spaces at the beginning of a code line.
#
# Python uses indentation to indicate a block of code.

# %%
for i in (1,2,3,4,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## Comments

# %% [markdown]
# Comments can be used to improve readability, clarity and to prevent execution

# %%
#Just for the test
no_of_developers=5
no_of_testers=10
print(no_of_testers)
print(no_of_developers)
# Out:
# 10
# 5

# %%
def goo():
    """
testing triple quotes

"""
print("Lorout")
# Out:
# Lorout

# %% [markdown]
# # Variables

# %% [markdown]
# Python has no command for declaring a variable.
#
# A variable is created the moment you first assign a value to it.
#
# String variables can be declared either by using single or double quotes
#
# Variable names are case-sensitive.

# %%
input("Enter your location")
# Out:
# Enter your locationBangalore
# 'Bangalore'

# %%
a=5
A=10
print(a)
print(A)
# Out:
# 5
# 10
# Data science

# %% [markdown]
# ### Variable Casting
#
# If you want to specify the data type of a variable, this can be done with casting.

# %%
a="55"
b="10"
a=int(a)
b=int(b)
print(a+b)
# Out:
# 65

# %%
a=int(3)
b=str(3)
c=float(3)
print(a)
print(b)
print(c)
# Out:
# 3
# 3
# 3.0

# %% [markdown]
# ##### Rules for python variable name
#
# A variable name must start with a letter or the underscore character
#
# A variable name cannot start with a number
#
# A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
#
# Variable names are case-sensitive (age, Age and AGE are three different variables)

# %%
newvar = "Data"
new_var = "Data"
_new_var = "Data"
newVar = "Data"
NEWVAR = "Data"
newvar2 = "Data"

# %%
#Wrong variable names 

#2newvar = "Data"
new-var = "Data"
new var = "Data"
# Out:
#   Input In [7]
#     new-var = "Data"
#     ^
# SyntaxError: cannot assign to operator

# %% [markdown]
# Variable names with more than one word can be difficult to read.
#
# There are several techniques you can use to make them more readable
#
# Camel case
#
# Pascal case
#
# Snake case

# %%
#newvariablename

# Camel case

#Each word, except the first, starts with a capital letter:

newVariableName="Data"

# %%
#Pascal case

#Each word, except the first, starts with a capital letter

NewVariableName="Data"

# %%
#Snake case

#Each word is separated by an underscore character

new_variable_name="Data"

# %% [markdown]
# ### Print the variables
#
# In the print() function, you print multiple variables, separated by a comma (,) or operator (+)
#
# For numbers, the + character works as a mathematical operator
#
# In the print() function, when you try to combine a string and a number with the + operator, Python will give you an error
#
# The best way to print multiple variables in the print() function is to separate them with commas, which even support different data types

# %%
x = "Python "
y = "is "
z = "awesome"
a=5
b=10
print(x , y , z)
print(x + y + z)
print(a+b)



print(a,b)
print(x+str(a))
# Out:
# Python  is  awesome
# Python is awesome
# 15
# 5 10
# Python 5

# %% [markdown]
# # Data types
#
#
# A data type, in programming, is a classification that specifies which type of value a variable has and what type of mathematical, relational or logical operations can be applied to it without causing an error.
#
# ![data%20types.jpg](attachment:data%20types.jpg)
#
# Variables can store data of different types, and different types can do different things.

# %%
#You can get the data type of any object by using the type() function

var1 = 25
print(type(var1))
# Out:
# <class 'int'>

# %% [markdown]
# ### Get the type

# %%
a=float(5)
b="Data science"
print(type(a))
print(type(b))
# Out:
# <class 'float'>
# <class 'str'>

# %% [markdown]
# ## Python Numbers
#
# There are three numeric types in Python
#
# int - Int, or integer, is a whole number, positive or negative, without decimals, of unlimited length
#
# float - Float, or "floating point number" is a number, positive or negative, containing one or more decimals.
#
# complex - Complex numbers are written with a "j" as the imaginary part

# %%
var_int = 1
var_float = 1.5
var_complex = -5j

print(type(var_int))
print(type(var_float))
print(type(var_complex))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
#You can convert from one type to another with the int(), float(), and complex() methods

x = 1    # int
y = 2.8  # float
z = 1j   # complex

#convert from int to float:
a = float(x)

#convert from float to int:
b = int(y)

#convert from int to complex:
c = complex(x)

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# 1.0
# 2
# (1+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %% [markdown]
# # Python operators
#
# Operators are used to perform operations on variables and values
#
# Python divides the operators in the following groups:
#
# Arithmetic operators
#
# Assignment operators
#
# Comparison operators
#
# Logical operators
#
# Identity operators
#
# Membership operators
#
# Bitwise operators
#
# https://www.geeksforgeeks.org/python-operators/

# %%
a=5
b=10
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
# Out:
# 15
# -5
# 50
# 0.5
# 0

# %% [markdown]
# # Strings
#
# Strings in python are surrounded by either single quotation marks, or double quotation marks.

# %%
a="data science"
b='data science'
print(a)
print(b)
# Out:
# data science
# data science

# %% [markdown]
# ### Accessing each character of a string
#
# Each element of a string can be accessed with square brackets [  ]

# %%
a="data science"
print(a[1])
# Out:
# a

# %%
# String Length
a="data science"
print(len(a))
# Out:
# 12

# %% [markdown]
# # Slicing
#
# You can return a range of characters by using the slice syntax.![string%20slicing.PNG](attachment:string%20slicing.PNG)
#
# Specify the start index and the end index, separated by a colon, to return a part of the string.
#
# Use negative indexes to start the slice from the end of the string:

# %%
a="data science"
print(a[3::])
print(a[-7::])
# Out:
# a science
# science

# %% [markdown]
# # String Operations
#
# Python has a set of built-in methods that you can use on strings.

# %%
# The replace() method replaces a string with another string

a="data science"
b=a.replace("d","T")
print(a)
print(b)
# Out:
# data science
# Tata science

# %%
# The upper() method returns the string in upper case

a="data science"
b=a.upper()
print(a)
print(b)
# Out:
# data science
# DATA SCIENCE

# %% [markdown]
# #### Please look into the String operation sheet in Python.xlsx to learn more about string operation methods

# %% [markdown]
# # String Concatenation
#
#
# To concatenate, or combine, two strings you can use the + operator.

# %%
a="data"
b="science"
print(a +" "+ b)
# Out:
# data science

# %% [markdown]
# ### Format Strings
#
# We cannot combine strings and numbers
#
# but we can combine strings and numbers by using the format() method
#
# The format() method takes the passed arguments, formats them, and places them in the string where the placeholders {} are
#
# The format() method takes unlimited number of arguments, and are placed into the respective placeholders:

# %%
fuel_capacity= 100
distance= 600
str= "This truck can hold {} litres of fuel and travel for {} km"
print(str.format(fuel_capacity, distance))
# Out:
# This truck can hold 100 litres of fuel and travel for 600 km

# %% [markdown]
# ### Escape character
#
# To insert characters that are illegal in a string, use an escape character.
#
# An escape character is a backslash \ followed by the character you want to insert.
#
# ![escape%20string.PNG](attachment:escape%20string.PNG)

# %%
txt=""I will finish this report on time," Sally assured her boss"
print(txt)
# Out:
#   Input In [11]
#     txt=""I will finish this report on time," Sally assured her boss"
#           ^
# SyntaxError: invalid syntax

# %%
txt="\"I will finish this report on time,\" Sally assured her boss"
print(txt)
# Out:
# "I will finish this report on time," Sally assured her boss
